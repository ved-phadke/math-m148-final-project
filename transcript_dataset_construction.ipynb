# %% [markdown]
# <a href="https://colab.research.google.com/github/ved-phadke/math-m148-final-project/blob/main/transcript_dataset_construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transcripts
#
# Aim: output a dataset of all sources with the transcripts in one column for easy text processing.

# %% [markdown]
# ## Imports

# %%
# !pip install youtube_transcript_api
! pip install youtube_search
# !pip install lyricsgenius
# Out:
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.11/dist-packages (0.6.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2025.1.31)
# Collecting youtube_search
#   Downloading youtube_search-2.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube_search) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_search) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_search) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_search) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_search) (2025.1.31)
# Downloading youtube_search-2.1.2-py3-none-any.whl (3.4 kB)
# Installing collected packages: youtube_search
# Successfully installed youtube_search-2.1.2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from youtube_transcript_api import YouTubeTranscriptApi
import re
from youtube_search import YoutubeSearch
import lyricsgenius

# %% [markdown]
# ## Read in Data

# %%
stim_df = pd.read_csv('/content/Stimuli.csv')
stim_df.head()
# Out:
#                       Stimulus name  \
# 0                 Agnus Dei (Audio)
# 1          Misere Mei, Deus (Audio)
# 2  3rd Grade Dropout Speech (Audio)
# 3     Unbroken - Motivation (Audio)
# 4            Laughing Heart (Audio)
#
#                                         Description   \
# 0  The Flemish Radio Choir performs Samuel Barber...
# 1  Tenebrae Choir performs Gregorio Allegri’s Mis...
# 2  Rick Rigsby is an ordained minister, motivatio...
# 3  This motivational compilation, from a series b...
# 4  The Laughing Heart is a classic poem by Charle...
#
#                             URL
# 0  https://youtu.be/bFnbGevBnvY
# 1  https://youtu.be/3nakMFiPB0w
# 2  https://youtu.be/Yu23MU4vsIM
# 3  https://youtu.be/QRE2CUZxtQY
# 4  https://youtu.be/9COXybhp8p8

# %% [markdown]
# ## Function Declarations

# %%
def extract_video_id(url):
  """
  Extracts the video ID from a YouTube URL.

  Args:
    url: The YouTube URL.

  Returns:
    The video ID, or None if the URL is invalid.
  """
  match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11})", url)
  if match:
    return match.group(1)
  return None

# Apply the function to the 'URL' column
stim_df['video_id'] = stim_df['URL'].apply(extract_video_id)

# %%
def get_transcript(video_id):
    """
    Fetches the transcript for a given YouTube video ID using the YouTubeTranscriptApi.

    Parameters:
    video_id (str): The unique identifier for the YouTube video.

    Returns:
    list[dict] | None: A list of dictionaries containing the transcript text and timestamps,
                        or None if an error occurs.
    """
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return transcript
    except Exception as e:
        print(f"Error getting transcript for video ID {video_id}: {e}")
        return None

# Apply the function to extract transcripts for all video IDs in the DataFrame
stim_df['transcript'] = stim_df['video_id'].apply(get_transcript)
# Out:
# Error getting transcript for video ID bFnbGevBnvY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bFnbGevBnvY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 3nakMFiPB0w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3nakMFiPB0w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID gCrUi_tRN8g:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gCrUi_tRN8g! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID JRinyHJ_9-E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JRinyHJ_9-E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID T2Qv_Vms-Yw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=T2Qv_Vms-Yw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID D95hQkiRNrQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=D95hQkiRNrQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID w8Xasd9yS0A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=w8Xasd9yS0A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID Uln1fL0W9as:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Uln1fL0W9as! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 8WEGleZJzz0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8WEGleZJzz0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 1yRrgFYjl_M:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1yRrgFYjl_M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 9OMjUaQD1cw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9OMjUaQD1cw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID yEKe5xrAsyo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yEKe5xrAsyo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID hyQpXYFhL2A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=hyQpXYFhL2A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID n2ks3g5fySE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n2ks3g5fySE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID LY2BbmeAP6M:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=LY2BbmeAP6M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 7BLhxyMyNOc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7BLhxyMyNOc! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (7BLhxyMyNOc) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - fr ("French (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID mn26zmFwUNk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mn26zmFwUNk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID cEbh8SThLAA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cEbh8SThLAA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID kV06adZPr8k:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=kV06adZPr8k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 5LPzYo9Cins:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=5LPzYo9Cins! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (5LPzYo9Cins) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - it ("Italian (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID 6d6cYCyXjwQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6d6cYCyXjwQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID I03S2YCYdRc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=I03S2YCYdRc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID q8hSfUY36_U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=q8hSfUY36_U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID VMgdGswaI5s:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=VMgdGswaI5s! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error getting transcript for video ID Zxqjf34ncUY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Zxqjf34ncUY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
def search_and_get_transcript(stimulus_name):
    """
    Searches for a YouTube video based on a given stimulus name and retrieves its transcript.

    Parameters:
    stimulus_name (str): The name of the stimulus to search for on YouTube.

    Returns:
    str | None: The transcript as a single concatenated string if found, otherwise None.
    """
    try:
        # Search YouTube for the stimulus name, retrieving the top result
        results = YoutubeSearch(stimulus_name, max_results=1).to_dict()

        if results:
            video_id = results[0]['id']
            transcript = YouTubeTranscriptApi.get_transcript(video_id)

            # Join the transcript segments into a single string
            transcript_text = ' '.join([segment['text'] for segment in transcript])
            return transcript_text
        else:
            print(f"No search results found for: {stimulus_name}")
            return None
    except Exception as e:
        print(f"Error searching or getting transcript for {stimulus_name}: {e}")
        return None

# Iterate through the DataFrame and fill missing transcripts
for index, row in stim_df.iterrows():
    if row['transcript'] is None or not row['transcript']:  # Check for empty or None transcripts
        transcript = search_and_get_transcript(row['Stimulus name'])
        if transcript:
            stim_df.loc[index, 'transcript'] = transcript  # Store transcript as a single string
# Out:
# Error searching or getting transcript for Agnus Dei (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=K6yeaHNXsBs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Misere Mei, Deus (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=rs5bc_P1kKo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Hallelujah Choir (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nsBByTiKfyY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Clair de Lune (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JGJPVl7iQUM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Carl Sagan Pale Blue Dot (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FRcxjprhTGM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Radiohead - Reckoner (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9wCJPm19XYQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Sigur Rós – Hoppípolla (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nf2VhqaBIys! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Aramaic Choir (Audio):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=locW-9S00VU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Air France :
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=NhA0aL105Nw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Be Kind (Everything Everywhere All At Once):
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=YEg4gylAIk8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Interstellar with Hans Zimmer:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=2YA0OK7OFkk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Giving Is The Best Communication:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ROrz__LOIU4! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (ROrz__LOIU4) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - th ("Thai (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Italians Making Music on Balconies Under Coronavirus Quarantine:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=EBByYjjvNzs! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (EBByYjjvNzs) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
#  - en-US ("English (United States) - Captions")[TRANSLATABLE]
#
# (GENERATED)
#  - it ("Italian (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Hans Zimmer - Time:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=c56t7upa8Bk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Final Battle Scene Jurassic World:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FtCslvCjZEY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Rocky - Retrospective:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Oa_joiuHRmo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error searching or getting transcript for Aramaic Choir:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=locW-9S00VU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
# Initialize the Genius API with the provided API key
genius = lyricsgenius.Genius("HxfZBC6XbrLahNVVwSk8DrImZjg5Quwe3Q-fhxECkH3BCfqrxAYGFGrHQ4oeyFgW")
# Replace with your actual Genius API key

def get_lyrics(song_title, artist_name):
    """
    Fetches song lyrics from the Genius API based on song title and artist name.

    Parameters:
    song_title (str): The title of the song.
    artist_name (str): The name of the artist.

    Returns:
    str | None: The lyrics of the song as a single string if found, otherwise None.
    """
    try:
        song = genius.search_song(song_title, artist_name)
        if song:
            return song.lyrics
        else:
            print(f"Lyrics not found for {song_title} by {artist_name}")
            return None
    except Exception as e:
        print(f"Error getting lyrics for {song_title} by {artist_name}: {e}")
        return None

# Iterate through the DataFrame and fill missing transcripts with lyrics
for index, row in stim_df.iterrows():
    if row['transcript'] is None or not row['transcript']:  # Check for empty or missing transcripts
        parts = row['Stimulus name'].split(" - ")  # Assume format: "Artist - Song Title"

        if len(parts) == 2:
            song_title = parts[1].strip()
            artist_name = parts[0].strip()
            lyrics = get_lyrics(song_title, artist_name)
            if lyrics:
                stim_df.loc[index, 'transcript'] = lyrics  # Store lyrics as transcript
        else:
            print(f"Could not parse stimulus name: {row['Stimulus name']}")
stim_df.at[37, 'transcript'] = rocky
# Out:
# Requirement already satisfied: lyricsgenius in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from lyricsgenius) (4.13.3)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from lyricsgenius) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.6.0->lyricsgenius) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.6.0->lyricsgenius) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->lyricsgenius) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->lyricsgenius) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->lyricsgenius) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->lyricsgenius) (2025.1.31)
# ERROR: Operation cancelled by user
# Could not parse stimulus name: Agnus Dei (Audio)
# Could not parse stimulus name: Misere Mei, Deus (Audio)
# Could not parse stimulus name: Clair de Lune (Audio)
# Could not parse stimulus name: Aramaic Choir (Audio)
# Could not parse stimulus name: Air France
# Searching for "Time" by Hans Zimmer...
# Error getting lyrics for Time by Hans Zimmer: [Errno 403] 403 Client Error: Forbidden for url: https://genius.com/api/search/multi?q=Time+Hans+Zimmer
# Could not parse stimulus name: Aramaic Choir
#                                         Stimulus name  \
# 0                                   Agnus Dei (Audio)
# 1                            Misere Mei, Deus (Audio)
# 2                    3rd Grade Dropout Speech (Audio)
# 3                       Unbroken - Motivation (Audio)
# 4                              Laughing Heart (Audio)
# 5                            Hallelujah Choir (Audio)
# 6            Jason Silva - Existential Bummer (Audio)
# 7                               Clair de Lune (Audio)
# 8                    Carl Sagan Pale Blue Dot (Audio)
# 9                          Motorcycle Diaries (Audio)
# 10                               Pema Chodron (Audio)
# 11                             Duo des fleurs (Audio)
# 12                       Radiohead - Reckoner (Audio)
# 13                     Sigur Rós – Hoppípolla (Audio)
# 14                                 Wild Geese (Audio)
# 15                         The Great Dictator (Audio)
# 16      We Think Too Much and Feel Too Little (Audio)
# 17                              Aramaic Choir (Audio)
# 18           Dead Poet's Society - YAWP Scene (Audio)
# 19               The Feynmann Series - Beauty (Audio)
# 20                                        Air France
# 21        Be Kind (Everything Everywhere All At Once)
# 22                      Interstellar with Hans Zimmer
# 23                                Mr Rogers Testimony
# 24                                       Hunger Games
# 25                                        Cloud Atlas
# 26                                 A Thing About Life
# 27                             Remembering the Titans
# 28                       Amélie - Helping a Blind Man
# 29                   Giving Is The Best Communication
# 30                                        Unsung Hero
# 31                                       Muhammed Ali
# 32                                   A Perfect Planet
# 33  Italians Making Music on Balconies Under Coron...
# 34  Won't You Be My Neighbor? (Mr. Roger's Documen...
# 35                                 Hans Zimmer - Time
# 36                  Final Battle Scene Jurassic World
# 37                              Rocky - Retrospective
# 38                                 The Great Dictator
# 39              We Think Too Much and Feel Too Little
# 40                                      Aramaic Choir
# 41                  Dead Poet's Society - YAWP Scene
# 42                      The Feynmann Series - Beauty
#
#                                          Description   \
# 0   The Flemish Radio Choir performs Samuel Barber...
# 1   Tenebrae Choir performs Gregorio Allegri’s Mis...
# 2   Rick Rigsby is an ordained minister, motivatio...
# 3   This motivational compilation, from a series b...
# 4   The Laughing Heart is a classic poem by Charle...
# 5   Choir! Choir! Choir! began as a weekly drop-in...
# 6   Storyteller Jason Silva considers the imperman...
# 7   Claude Debussy’s “Clair de Lune,” (Suite berga...
# 8   On Feb. 14, 1990, astronomer Carl Sagan gave a...
# 9   De Ushuaia a La Quiaca (From Ushuaia to La Qui...
# 10  Pema Chodron is an American Tibetan Buddhist n...
# 11  Sabine Devieilhe and Marianne Crebassa perform...
# 12  Radiohead’s song Reckoner was born out of a dr...
# 13  Hoppípolla is a song by Icelandic band Sigur R...
# 14  Mary Oliver’s “Wild Geese” is a poetic guide t...
# 15  In the 1940 satire-drama The Great Dictator, C...
# 16  This inspirational content, from Youtube creat...
# 17  Father Serafim Bitbunov and the choir of the T...
# 18  At a prestigious boarding school, one student ...
# 19  Physicist Richard Feynman argues good-naturedl...
# 20  The beauty of human form in dance is celebrate...
# 21  In this sci-fi film, a man delivers an earnest...
# 22  In Earth's future, a global blight and Dust Bo...
# 23  In 1969, facing government budget cuts to publ...
# 24  In a dystopian future, a young woman reluctant...
# 25  In this scene from the science fiction film Cl...
# 26  This inspirational video, from Youtube creator...
# 27  After generations of segregation in Virginia, ...
# 28  After feeling the joy one gets from helping ot...
# 29  “Giving is the best communication.” This short...
# 30  A young man performs random acts of kindness t...
# 31  This inspiring video, from a series by Youtube...
# 32  A Perfect Planet is an awe-inspiring explorati...
# 33  While locked down under national quarantine in...
# 34  Mister Rogers' Neighborhood was a beloved and ...
# 35  Renowned film score composer Hans Zimmer perfo...
# 36  Set 22 years after the events of Jurassic Park...
# 37  Rocky is a boxing saga of popular films all st...
# 38  In the 1940 satire-drama The Great Dictator, C...
# 39  This inspirational content, from Youtube creat...
# 40  Father Serafim Bitbunov and the choir of the T...
# 41  At a prestigious boarding school, one student ...
# 42  Physicist Richard Feynman argues good-naturedl...
#
#                              URL     video_id  \
# 0   https://youtu.be/bFnbGevBnvY  bFnbGevBnvY
# 1   https://youtu.be/3nakMFiPB0w  3nakMFiPB0w
# 2   https://youtu.be/Yu23MU4vsIM  Yu23MU4vsIM
# 3   https://youtu.be/QRE2CUZxtQY  QRE2CUZxtQY
# 4   https://youtu.be/9COXybhp8p8  9COXybhp8p8
# 5   https://youtu.be/gCrUi_tRN8g  gCrUi_tRN8g
# 6   https://youtu.be/Lz-P3WdIHvw  Lz-P3WdIHvw
# 7   https://youtu.be/JRinyHJ_9-E  JRinyHJ_9-E
# 8   https://youtu.be/T2Qv_Vms-Yw  T2Qv_Vms-Yw
# 9   https://youtu.be/D95hQkiRNrQ  D95hQkiRNrQ
# 10  https://youtu.be/kAjDjzfVhGU  kAjDjzfVhGU
# 11  https://youtu.be/w8Xasd9yS0A  w8Xasd9yS0A
# 12  https://youtu.be/Uln1fL0W9as  Uln1fL0W9as
# 13  https://youtu.be/8WEGleZJzz0  8WEGleZJzz0
# 14  https://youtu.be/AfVHA6h9h0g  AfVHA6h9h0g
# 15  https://youtu.be/1yRrgFYjl_M  1yRrgFYjl_M
# 16  https://youtu.be/2RuL-gQ84jo  2RuL-gQ84jo
# 17  https://youtu.be/9OMjUaQD1cw  9OMjUaQD1cw
# 18  https://youtu.be/cmODysXCT4Q  cmODysXCT4Q
# 19  https://youtu.be/9579P23GlXk  9579P23GlXk
# 20  https://youtu.be/yEKe5xrAsyo  yEKe5xrAsyo
# 21  https://youtu.be/hyQpXYFhL2A  hyQpXYFhL2A
# 22  https://youtu.be/n2ks3g5fySE  n2ks3g5fySE
# 23  https://youtu.be/iiFEiUe8k8U  iiFEiUe8k8U
# 24  https://youtu.be/LY2BbmeAP6M  LY2BbmeAP6M
# 25  https://youtu.be/tnXHFqw1ckk  tnXHFqw1ckk
# 26  https://youtu.be/5MveHH5k10I  5MveHH5k10I
# 27  https://youtu.be/RbWWQbMqKdQ  RbWWQbMqKdQ
# 28  https://youtu.be/7BLhxyMyNOc  7BLhxyMyNOc
# 29  https://youtu.be/mn26zmFwUNk  mn26zmFwUNk
# 30  https://youtu.be/cEbh8SThLAA  cEbh8SThLAA
# 31  https://youtu.be/FjPv3B8jQmw  FjPv3B8jQmw
# 32  https://youtu.be/kV06adZPr8k  kV06adZPr8k
# 33  https://youtu.be/5LPzYo9Cins  5LPzYo9Cins
# 34  https://youtu.be/xJvF2sFKRcU  xJvF2sFKRcU
# 35  https://youtu.be/6d6cYCyXjwQ  6d6cYCyXjwQ
# 36  https://youtu.be/I03S2YCYdRc  I03S2YCYdRc
# 37  https://youtu.be/q8hSfUY36_U  q8hSfUY36_U
# 38  https://youtu.be/VMgdGswaI5s  VMgdGswaI5s
# 39  https://youtu.be/1QmdjvBmeaU  1QmdjvBmeaU
# 40  https://youtu.be/Zxqjf34ncUY  Zxqjf34ncUY
# 41  https://youtu.be/Oj-1rJn8-sU  Oj-1rJn8-sU
# 42  https://youtu.be/mauBfuFwLFI  mauBfuFwLFI
#
#                                            transcript
# 0                                                None
# 1                                                None
# 2   [{'text': 'the wisest person I ever met in my ...
# 3   [{'text': 'you can't connect the dots looking'...
# 4   [{'text': 'thank you', 'start': 1.68, 'duratio...
# 5   \n[Verse 1]\nNow I've heard there was a secret...
# 6   [{'text': 'foreign', 'start': 0.06, 'duration'...
# 7                                                None
# 8   \nFrom this distant vantage point, the Earth m...
# 9   the Motorcycle Diaries notes on a Latin Americ...
# 10  [{'text': 'so what kind of world are we creati...
# 11  Come, Mallika, the flowering lianas Already ca...
# 12  [Verse 1] Reckoner\nYou can'\t take it with yo...
# 13  \nYou think I’m weak don’t you?\nWhen we first...
# 14  [{'text': 'thank you', 'start': 12.259, 'durat...
# 15  i'm sorry but i don't want to be an emperor th...
# 16  [{'text': 'foreign', 'start': 2.46, 'duration'...
# 17                                               None
# 18  [{'text': 'now in addition to your essays I wo...
# 19  [{'text': 'foreign', 'start': 2.22, 'duration'...
# 20                                               None
# 21  \nYou think I’m weak don’t you?\nWhen we first...
# 22  \nMurph.\nDad.\nPlease.\nYou told them I like ...
# 23  [{'text': 'now Mr Rogers is certainly one of t...
# 24  \n[Verse 1]\nAre you, are you\nComing to the t...
# 25  [{'text': 'sick Smith I climbed the steps of t...
# 26  [{'text': 'the thing about life is', 'start': ...
# 27  [{'text': 'foreign', 'start': 0.06, 'duration'...
# 28  She breathes deeply.\nLife is simple and clear...
# 29  \nWhat did you take out?\nWhat did you do with...
# 30  [Music] Once Upon a Time you 25 walking up the...
# 31  [{'text': 'foreign', 'start': 0.26, 'duration'...
# 32  you are so beautiful they say perfection doesn...
# 33  [{'text': '[chiming]', 'start': 0.105, 'durati...
# 34  [{'text': 'foreign', 'start': 0.0, 'duration':...
# 35                                               None
# 36  \nOWEN\nThat's how it is?\nEasy. Easy.\nEasy. ...
# 37  [{'text': 'I was thinking it really don't matt...
# 38  [Music] [Music] [Applause] [Music] [Applause] ...
# 39  [{'text': 'foreign', 'start': 2.46, 'duration'...
# 40                                               None
# 41  [{'text': 'now in addition to your essays I wo...
# 42  [{'text': 'foreign', 'start': 2.22, 'duration'...

# %%
def process_transcripts(df):
    """
    Processes the 'transcript' column in a DataFrame by converting transcript lists into
    single concatenated text strings.

    Parameters:
    df (pd.DataFrame): DataFrame containing a 'transcript' column.

    Returns:
    pd.DataFrame: The modified DataFrame with transcripts formatted as single strings.
    """
    def join_transcript_texts(transcript_list):
        """
        Joins a list of transcript segments into a single text string.

        Parameters:
        transcript_list (list | str): A list of dictionaries containing transcript text,
                                      or a pre-existing transcript string.

        Returns:
        str: The joined transcript text if the input is a list, otherwise returns the input as is.
        """
        if isinstance(transcript_list, list):
            joined_text = ' '.join([item['text'] for item in transcript_list if isinstance(item, dict) and 'text' in item])
            return joined_text
        else:
            return transcript_list  # Return as is if not a list

    # Apply transformation to the 'transcript' column
    df['transcript'] = df['transcript'].apply(join_transcript_texts)

    return df

# Process transcripts in the DataFrame
stim_df = process_transcripts(stim_df)

# Create a new column indicating whether a transcript is present (True) or missing (False)
stim_df['only_music'] = stim_df['transcript'].astype(bool)

# Save the processed DataFrame to a CSV file
stim_df.to_csv('stim_df.csv', index=False)
